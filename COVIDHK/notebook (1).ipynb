# %%
import plotly.express as px
import plotly.graph_objects as go

import pandas as pd

from io import StringIO
import requests

# %%
url_enhanced_sur_covid_19_eng = 'https://www.chp.gov.hk/files/misc/enhanced_sur_covid_19_eng.csv'
url_large_clusters_eng = 'https://www.chp.gov.hk/files/misc/large_clusters_eng.csv'

r = requests.get(url_enhanced_sur_covid_19_eng)
df_covid = pd.read_csv(StringIO(r.text))

r = requests.get(url_large_clusters_eng)
df_cluster = pd.read_csv(StringIO(r.text))

#Cleaning data

# Remove all the capital, non capital confusion
df_covid["HK/Non-HK resident"] = df_covid["HK/Non-HK resident"].str.upper()

# Convert Date to datetime format
df_covid["Report date"] = pd.to_datetime(df_covid["Report date"], infer_datetime_format=True)

# Cannot convert due to Asymptomatic entity
# df["Date of onset"] = pd.to_datetime(df["Date of onset"], infer_datetime_format=True)

## Second file
df_cluster["Case no."] = df_cluster[["Involved case number"]].applymap(lambda x: int(x.split(",")[0]))
# df_cluster[["Involved case number count"]] = df_cluster[["Involved case number"]].applymap(lambda x: len(x.split(","))) Done

df_cluster2 = pd.merge(df_covid, df_cluster, left_on="Case no.", right_on="Case no.")[["Cluster", "Report date", "Number of cases","Case no."]]

# %%
df_cluster2
# Out:
# Empty DataFrame
# Columns: [Cluster, Report date, Number of cases, Case no.]
# Index: []

# %% [markdown]
# # Cleansing the dataset

# %%
df_covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15414 entries, 0 to 15413
# Data columns (total 10 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Case no.                          15414 non-null  int64
#  1   Report date                       15414 non-null  datetime64[ns]
#  2   Date of onset                     15395 non-null  object
#  3   Gender                            15408 non-null  object
#  4   Age                               15408 non-null  object
#  5   Name of hospital admitted         0 non-null      float64
#  6   Hospitalised/Discharged/Deceased  15408 non-null  object
#  7   HK/Non-HK resident                15408 non-null  object
#  8   Classification*                   15408 non-null  object
#  9   Case status*                      15414 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(7)
# memory usage: 1.2+ MB

# %%
df_cluster2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Cluster          0 non-null      object
#  1   Report date      0 non-null      datetime64[ns]
#  2   Number of cases  0 non-null      object
#  3   Case no.         0 non-null      int64
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 0.0+ bytes

# %% [markdown]
# # Function Declaration

# %%
def df_column_draw_pie_chart(df, columnName, figTitle):

    df_nona = df[[columnName]].dropna()

    labels = [arr for arr in df_nona[columnName].unique()]
    values = [df_nona[columnName].value_counts()[label] for _,label in enumerate(labels)]
    fig = go.Figure(data=[go.Pie(labels=labels, 
                                    values=values, 
                                    title=figTitle,
                                )
                        ]
                    )
    return fig

def df_column_count_line_chart(df, columnName, figTitle, mode="count"):
    df_countByDate = df_covid[columnName].value_counts().sort_index()
    if mode == "count":
        fig = px.line(df_countByDate, title=figTitle)
    elif mode == "cumsum":
        fig = px.line(df_countByDate.cumsum(), title=figTitle)
    return fig

def df_column_histogram(df, columnName, figTitle):
    fig = px.histogram(df, x=columnName, title=figTitle)
    return fig

def df_bubble_chart(df, dfx, dfy, dfsize, hoverName, titleName):
    fig = px.scatter(df, x=dfx,y=dfy,
	                    size=dfsize,  
                        hover_name=hoverName, size_max=60, title=titleName)
    return fig

# %%
def go_df_plot(df,dfx,dfy,lineName):
    go_obj = go.Scatter(x=df[dfx].to_list(), y=df[dfy].to_list(),
                    mode='lines',
                    name=lineName)
    return go_obj

def go_df_count_plot(df,dfx,lineName,mode="count"):
    df_countByDate = df[dfx].value_counts().sort_index()
    if mode == 'cumsum':
        df_countByDate = df_countByDate.cumsum()
    go_obj = go.Scatter(x=df_countByDate.index.to_list(),y=df_countByDate.to_list(),
                    mode='lines',
                    name=lineName)
    return go_obj

def go_df_bubble_chart(df,dfx,dfy,dfsize,dfhover, lineName):
    go_obj = go.Scatter(
        x=df[dfx].to_list(), y=df[dfy].to_list(),
        mode='markers',
        marker=dict(
            size=df[dfsize].to_list(),
            sizemode='area',
            sizeref=0.2,
            sizemin=1,
        ),
        hovertext=df[dfhover].to_list(),
        name=lineName,
    )
    return go_obj

# %% [markdown]
# # Application

# %% [markdown]
# ## Total of the Infected

# %%
df_covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15414 entries, 0 to 15413
# Data columns (total 10 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Case no.                          15414 non-null  int64
#  1   Report date                       15414 non-null  datetime64[ns]
#  2   Date of onset                     15395 non-null  object
#  3   Gender                            15408 non-null  object
#  4   Age                               15408 non-null  object
#  5   Name of hospital admitted         0 non-null      float64
#  6   Hospitalised/Discharged/Deceased  15408 non-null  object
#  7   HK/Non-HK resident                15408 non-null  object
#  8   Classification*                   15408 non-null  object
#  9   Case status*                      15414 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(7)
# memory usage: 1.2+ MB

# %% [markdown]
# ## Ratio of Male and Female

# %%
df_nona = df_covid[['Gender']].dropna()
df_nona
# Out:
#       Gender
# 0          M
# 1          M
# 2          F
# 3          F
# 4          M
# ...      ...
# 15409      F
# 15410      M
# 15411      F
# 15412      M
# 15413      M
#
# [15408 rows x 1 columns]

# %%
df_column_draw_pie_chart(df_covid,'Gender', 'Gender of the infected').show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.6.3.min.js"></script>                <div id="b5eda381-ad8d-4ceb-8de4-f46d0968316b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b5eda381-ad8d-4ceb-8de4-f46d0968316b")) {                    Plotly.newPlot(                        "b5eda381-ad8d-4ceb-8de4-f46d0968316b",                        [{"labels":["M","F","Pending"],"title":{"text":"Gender of the infected"},"values":[7408,7992,8],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"marker":{"colorbar":{ ...

# %% [markdown]
# ## Citizenship

# %%
df_column_draw_pie_chart(df_covid, 'HK/Non-HK resident', 'Origin of the infected').show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.6.3.min.js"></script>                <div id="2f9791eb-791a-48c6-b508-a7dd0395fedf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2f9791eb-791a-48c6-b508-a7dd0395fedf")) {                    Plotly.newPlot(                        "2f9791eb-791a-48c6-b508-a7dd0395fedf",                        [{"labels":["NON-HK RESIDENT","HK RESIDENT","PENDING"],"title":{"text":"Origin of the infected"},"values":[808,14592,8],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo": ...

# %% [markdown]
# # Classification of the cases in Hong Kong

# %%
df_covid
# Out:
#        Case no. Report date Date of onset Gender Age  \
# 0             1  2020-01-23    21/01/2020      M  39
# 1             2  2020-01-23    18/01/2020      M  56
# 2             3  2020-01-24    20/01/2020      F  62
# 3             4  2020-01-24    23/01/2020      F  62
# 4             5  2020-01-24    23/01/2020      M  63
# ...         ...         ...           ...    ...  ..
# 15409     15410  2022-02-06    04/02/2022      F  16
# 15410     15411  2022-02-06    04/02/2022      M  35
# 15411     15412  2022-02-06    03/02/2022      F  14
# 15412     15413  2022-02-06    31/01/2022      M  48
# 15413     15414  2022-02-06    31/01/2022      M  13
#
#        Name of hospital admitted Hospitalised/Discharged/Deceased  \
# 0                            NaN                       Discharged
# 1                            NaN                       Discharged
# 2                            NaN                       Discharged
# 3                            NaN                       Discharged
# 4                            NaN                       Discharged
# ...                          ...                              ...
# 15409                        NaN                Pending admission
# 15410                        NaN                     Hospitalised
# 15411                        NaN                     Hospitalised
# 15412                        NaN                Pending admission
# 15413                        NaN                Pending admission
#
#       HK/Non-HK resident        Classification* Case status*
# 0        NON-HK RESIDENT          Imported case    Confirmed
# 1            HK RESIDENT          Imported case    Confirmed
# 2        NON-HK RESIDENT          Imported case    Confirmed
# 3        NON-HK RESIDENT          Imported case    Confirmed
# 4        NON-HK RESIDENT          Imported case    Confirmed
# ...                  ...                    ...          ...
# 15409        HK RESIDENT  Locally acquired case    Confirmed
# 15410        HK RESIDENT  Locally acquired case    Confirmed
# 15411        HK RESIDENT  Locally acquired case    Confirmed
# 15412        HK RESIDENT  Locally acquired case    Confirmed
# 15413        HK RESIDENT  Locally acquired case    Confirmed
#
# [15414 rows x 10 columns]

# %%
df_column_draw_pie_chart(df_covid, 'Classification*', 'Classification of the cases').show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.6.3.min.js"></script>                <div id="332564d7-b6c5-4a45-bf71-5f699b390c8d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("332564d7-b6c5-4a45-bf71-5f699b390c8d")) {                    Plotly.newPlot(                        "332564d7-b6c5-4a45-bf71-5f699b390c8d",                        [{"labels":["Imported case","Epidemiologically linked with imported case","Possibly local case","Local case","Epidemiologically linked with local case","Epidemiologically linked with possibly local case","Locally acquired case"],"title":{"text":"Classification of the cases"},"values":[3835,61,103,3158,6021,62,2168],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth" ...

# %% [markdown]
# ## Hisogram of the infected age

# %%
df_column_histogram(df_covid, "Age", "Histogram of the infected age")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.6.3.min.js"></script>                <div id="55c1c6b2-ae37-485e-a3d1-a4b8acad60fc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("55c1c6b2-ae37-485e-a3d1-a4b8acad60fc")) {                    Plotly.newPlot(                        "55c1c6b2-ae37-485e-a3d1-a4b8acad60fc",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Age=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["39","56","62","62","63","47","68","64","73","72","37","75","39","80","72","64","60","25","28","56","56","55","63","65","58","42","24","70","91","68","57","22","50","25","51","23","55","69","63","86","52","62","59","60","71","75","66","37","37","51","43","67","37","41","70","61","54","69","45","46","32","58","83","68","70","75","38","58","48","96","68","62","80","76","35","57","68","59","58","57","57","33","55","24","60","49","21","16","80","29","26","70","89","61","46","68","56","71","76","79","63","43","57","62","69","56","84","69","38","73","76","55","47","41","59","44","52","48","59","59","59","22","57","59","23","63","63","36","52","31","37","31","1","67","30","61","54","66","39","59","28","59","35","29","37","39","61","58","32","37","30","73","26","42","58","59","42","41","69","18","37","36","30","21","24","27","25","43","34","36","27","28","55","31","29","29","28","29","63","38","63","50","24","64","23","46","20","16","49","12","34","46","33","44","29","48","19","21","29","22","35","19","29","43","35","40","32","44","51","46","33","44","4","41","61","21","35","54","13","57","62","31","31","38","61","17","28","50","40","23","24","16","31","52","18","32","29","69","50","33","60","61","25","36","46","58","34","33","19","27","38","23","31","27","22","30","18","58","35","43","61","70","50","28","19","48","30","60","15","35","51","11","36","36","30","29","27","28","30","20","33","39","20","26","41","37","31","20","20","18","32","17","36","30","31","24","18","1","40","36","72","19","1","69","26","64","31","39","56","33","16","56","29","28","45","29","24","41","25","20","57","61","20","36","34","48","51","47","21","30","21","32","56","18","19","43","66","62","32","39","54","41","39","23","37","30","54","66","26","57","58","43","33","50","25","18","18","41","61","30","38","34","52","21","44","42","38","32","36","26","66","54","33","60","39","40","40","36","47","42","15","26","39","26","50","48","38","36","43","30","57","33","18","28","29","28","48","16","21","11","51","26","45","50","41","50","20","18","20","36","38","32","48","46","47","20","65","20","20","27","25","31","36","18","18","19","74","22","48","19","20","39","47","30","44","23","27","42","19","40","30","58","78","63","26","21","37","20","19","38","30","25","50","32","33","62","45","25","23","56","60","34","51","61","56","36","48","15","24","18","19","22","23","26","33","47","52","22","71","52","31","17","41","34","18","21","39","19","23","27","15","50","50","18","31","17","27","58","48","18","35","42","12","62","23","18","49","48","40","62","37","23","36","45","30","38","30","20","37","35","56","38","38","56","63","52","48","29","41","60","42","19","25","24","28","31","20","19","19","18","17","18","25","20","19","23","18","16","16","19","20","20","20","21","23","20","19","20","19","20","67","25","27","33","66","31","21","26","61","15","76","56","65","56","31","36","15","7","34","26","42","31","19","63","28","38","29","29","22","56","15","14","20","16","75","67","21","17","62","23","18","19","16","38","19","28","46","27","21","35","56","11","14","31","28","20","31","29","58","58","59","47","38","47","51","37","67","21","36","32","49","77","74","48","40","21","28","39","21","23","34","23","32","13","27" ...

# %% [markdown]
# ## Number of infected case

# %%
df_column_count_line_chart(df_covid, 'Report date', 'Infected People Daily')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.6.3.min.js"></script>                <div id="02f31875-425f-420a-8aab-d0d087d50fa6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("02f31875-425f-420a-8aab-d0d087d50fa6")) {                    Plotly.newPlot(                        "02f31875-425f-420a-8aab-d0d087d50fa6",                        [{"hovertemplate":"variable=Report date<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Report date","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Report date","orientation":"v","showlegend":true,"x":["2020-01-23T00:00:00","2020-01-24T00:00:00","2020-01-26T00:00:00","2020-01-29T00:00:00","2020-01-30T00:00:00","2020-01-31T00:00:00","2020-02-01T00:00:00","2020-02-04T00:00:00","2020-02-05T00:00:00","2020-02-06T00:00:00","2020-02-07T00:00:00","2020-02-09T00:00:00","2020-02-10T00:00:00","2020-02-11T00:00:00","2020-02-12T00:00:00","2020-02-13T00:00:00","2020-02-14T00:00:00","2020-02-16T00:00:00","2020-02-17T00:00:00","2020-02-18T00:00:00","2020-02-19T00:00:00","2020-02-20T00:00:00","2020-02-22T00:00:00","2020-02-23T00:00:00","2020-02-24T00:00:00","2020-02-25T00:00:00","2020-02-26T00:00:00","2020-02-27T00:00:00","2020-02-28T00:00:00","2020-02-29T00:00:00","2020-03-01T00:00:00","2020-03-02T00:00:00","2020-03-04T00:00:00","2020-03-06T00:00:00","2020-03-07T00:00:00","2020-03-08T00:00:00","2020-03-09T00:00:00","2020-03-10T00:00:00","2020-03-11T00:00:00","2020-03-12T00:00:00","2020-03-13T00:00:00","2020-03-14T00:00:00","2020-03-15T00:00:00","2020-03-16T00:00:00","2020-03-17T00:00:00","2020-03-18T00:00:00","2020-03-19T00:00:00","2020-03-20T00:00:00","2020-03-21T00:00:00","2020-03-22T00:00:00","2020-03-23T00:00:00","2020-03-24T00:00:00","2020-03-25T00:00:00","2020-03-26T00:00:00","2020-03-27T00:00:00","2020-03-28T00:00:00","2020-03-29T00:00:00","2020-03-30T00:00:00","2020-03-31T00:00:00","2020-04-01T00:00:00","2020-04-02T00:00:00","2020-04-03T00:00:00","2020-04-04T00:00:00","2020-04-05T00:00:00","2020-04-06T00:00:00","2020-04-07T00:00:00","2020-04-08T00:00:00","2020-04-09T00:00:00","2020-04-10T00:00:00","2020-04-11T00:00:00","2020-04-12T00:00:00","2020-04-13T00:00:00","2020-04-14T00:00:00","2020-04-15T00:00:00","2020-04-16T00:00:00","2020-04-17T00:00:00","2020-04-18T00:00:00","2020-04-19T00:00:00","2020-04-21T00:00:00","2020-04-22T00:00:00","2020-04-23T00:00:00","2020-04-25T00:00:00","2020-05-01T00:00:00","2020-05-04T00:00:00","2020-05-07T00:00:00","2020-05-10T00:00:00","2020-05-13T00:00:00","2020-05-14T00:00:00","2020-05-15T00:00:00","2020-05-17T00:00:00","2020-05-21T00:00:00","2020-05-22T00:00:00","2020-05-27T00:00:00","2020-05-29T00:00:00","2020-05-30T00:00:00","2020-05-31T00:00:00","2020-06-01T00:00:00","2020-06-02T00:00:00","2020-06-04T00:00:00","2020-06-05T00:00:00","2020-06-06T00:00:00","2020-06-07T00:00:00","2020-06-08T00:00:00","2020-06-12T00:00:00","2020-06-13T00:00:00","2020-06-15T00:00:00","2020-06-17T00:00:00","2020-06-18T00:00:00","2020-06-19T00:00:00","2020-06-20T00:00:00","2020-06-21T00:00:00","2020-06-22T00:00:00","2020-06-23T00:00:00","2020-06-24T00:00:00","2020-06-25T00:00:00","2020-06-26T00:00:00","2020-06-27T00:00:00","2020-06-28T00:00:00","2020-06-29T00:00:00","2020-06-30T00:00:00","2020-07-01T00:00:00","2020-07-02T00:00:00","2020-07-03T00:00:00","2020-07-04T00:00:00","2020-07-05T00:00:00","2020-07-06T00:00:00","2020-07-07T00:00:00","2020-07-08T00:00:00","2020-07-09T00:00:00","2020-07-10T00:00:00","2020-07-11T00:00:00","2020-07-12T00:00:00","2020-07-13T00:00:00","2020-07-14T00:00:00","2020-07-15T00:00:00","2020-07-16T00:00:00","2020-07-17T00:00:00","2020-07-18T00:00:00","2020-07-19T00:00:00","2020-07-20T00:00:00","2020-07-21T00:00:00","2020-07-22T00:00:00","2020-07-23T00:00:00","2020-07-24T00:00:00","2020-07-25T00:00:00","202 ...

# %%
df_column_count_line_chart(df_covid, 'Report date', 'Infected People Daily', 'cumsum')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.6.3.min.js"></script>                <div id="af7177c7-9cf4-4aff-a6d0-a84024cc71f4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("af7177c7-9cf4-4aff-a6d0-a84024cc71f4")) {                    Plotly.newPlot(                        "af7177c7-9cf4-4aff-a6d0-a84024cc71f4",                        [{"hovertemplate":"variable=Report date<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Report date","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Report date","orientation":"v","showlegend":true,"x":["2020-01-23T00:00:00","2020-01-24T00:00:00","2020-01-26T00:00:00","2020-01-29T00:00:00","2020-01-30T00:00:00","2020-01-31T00:00:00","2020-02-01T00:00:00","2020-02-04T00:00:00","2020-02-05T00:00:00","2020-02-06T00:00:00","2020-02-07T00:00:00","2020-02-09T00:00:00","2020-02-10T00:00:00","2020-02-11T00:00:00","2020-02-12T00:00:00","2020-02-13T00:00:00","2020-02-14T00:00:00","2020-02-16T00:00:00","2020-02-17T00:00:00","2020-02-18T00:00:00","2020-02-19T00:00:00","2020-02-20T00:00:00","2020-02-22T00:00:00","2020-02-23T00:00:00","2020-02-24T00:00:00","2020-02-25T00:00:00","2020-02-26T00:00:00","2020-02-27T00:00:00","2020-02-28T00:00:00","2020-02-29T00:00:00","2020-03-01T00:00:00","2020-03-02T00:00:00","2020-03-04T00:00:00","2020-03-06T00:00:00","2020-03-07T00:00:00","2020-03-08T00:00:00","2020-03-09T00:00:00","2020-03-10T00:00:00","2020-03-11T00:00:00","2020-03-12T00:00:00","2020-03-13T00:00:00","2020-03-14T00:00:00","2020-03-15T00:00:00","2020-03-16T00:00:00","2020-03-17T00:00:00","2020-03-18T00:00:00","2020-03-19T00:00:00","2020-03-20T00:00:00","2020-03-21T00:00:00","2020-03-22T00:00:00","2020-03-23T00:00:00","2020-03-24T00:00:00","2020-03-25T00:00:00","2020-03-26T00:00:00","2020-03-27T00:00:00","2020-03-28T00:00:00","2020-03-29T00:00:00","2020-03-30T00:00:00","2020-03-31T00:00:00","2020-04-01T00:00:00","2020-04-02T00:00:00","2020-04-03T00:00:00","2020-04-04T00:00:00","2020-04-05T00:00:00","2020-04-06T00:00:00","2020-04-07T00:00:00","2020-04-08T00:00:00","2020-04-09T00:00:00","2020-04-10T00:00:00","2020-04-11T00:00:00","2020-04-12T00:00:00","2020-04-13T00:00:00","2020-04-14T00:00:00","2020-04-15T00:00:00","2020-04-16T00:00:00","2020-04-17T00:00:00","2020-04-18T00:00:00","2020-04-19T00:00:00","2020-04-21T00:00:00","2020-04-22T00:00:00","2020-04-23T00:00:00","2020-04-25T00:00:00","2020-05-01T00:00:00","2020-05-04T00:00:00","2020-05-07T00:00:00","2020-05-10T00:00:00","2020-05-13T00:00:00","2020-05-14T00:00:00","2020-05-15T00:00:00","2020-05-17T00:00:00","2020-05-21T00:00:00","2020-05-22T00:00:00","2020-05-27T00:00:00","2020-05-29T00:00:00","2020-05-30T00:00:00","2020-05-31T00:00:00","2020-06-01T00:00:00","2020-06-02T00:00:00","2020-06-04T00:00:00","2020-06-05T00:00:00","2020-06-06T00:00:00","2020-06-07T00:00:00","2020-06-08T00:00:00","2020-06-12T00:00:00","2020-06-13T00:00:00","2020-06-15T00:00:00","2020-06-17T00:00:00","2020-06-18T00:00:00","2020-06-19T00:00:00","2020-06-20T00:00:00","2020-06-21T00:00:00","2020-06-22T00:00:00","2020-06-23T00:00:00","2020-06-24T00:00:00","2020-06-25T00:00:00","2020-06-26T00:00:00","2020-06-27T00:00:00","2020-06-28T00:00:00","2020-06-29T00:00:00","2020-06-30T00:00:00","2020-07-01T00:00:00","2020-07-02T00:00:00","2020-07-03T00:00:00","2020-07-04T00:00:00","2020-07-05T00:00:00","2020-07-06T00:00:00","2020-07-07T00:00:00","2020-07-08T00:00:00","2020-07-09T00:00:00","2020-07-10T00:00:00","2020-07-11T00:00:00","2020-07-12T00:00:00","2020-07-13T00:00:00","2020-07-14T00:00:00","2020-07-15T00:00:00","2020-07-16T00:00:00","2020-07-17T00:00:00","2020-07-18T00:00:00","2020-07-19T00:00:00","2020-07-20T00:00:00","2020-07-21T00:00:00","2020-07-22T00:00:00","2020-07-23T00:00:00","2020-07-24T00:00:00","2020-07-25T00:00:00","202 ...

# %% [markdown]
# ## Clustering of the cases

# %%
df_cluster2
# Out:
# Empty DataFrame
# Columns: [Cluster, Report date, Number of cases, Case no.]
# Index: []

# %%
df_bubble_chart(df_cluster2, "Report date", "Case no.", "Number of cases", "Cluster", "Cluster of the infected cases").show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.6.3.min.js"></script>                <div id="9f4bebf1-098d-4c49-93d8-317f2821644c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9f4bebf1-098d-4c49-93d8-317f2821644c")) {                    Plotly.newPlot(                        "9f4bebf1-098d-4c49-93d8-317f2821644c",                        [],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattergeo"}],"scattergl":[{"marker":{"colorbar":{"outlinewidth":0,"ti ...

# %% [markdown]
# # Summary

# %%
from plotly.subplots import make_subplots

# Create figure with secondary y-axis
fig = make_subplots(specs=[[{"secondary_y": True}]])

# fig.add_trace(go_df_bubble_chart(df_cluster2,"Report date","Case no.","Number of cases","Cluster", lineName="Big Cluster"))
fig.add_trace(go_df_count_plot(df_covid,"Report date", lineName="Total Infected Case",mode="cumsum"))
fig.add_trace(go_df_count_plot(df_covid,"Report date", lineName="Daily Infected Case",mode="count"), secondary_y=True)

# Add figure title
fig.update_layout(
    title_text="Summary of Hong Kong COVID19 Cases"
)

# Set x-axis title
fig.update_xaxes(title_text="Date")

# Set y-axes titles
fig.update_yaxes(title_text="<b>Total</b> Cases", secondary_y=False)
fig.update_yaxes(title_text="<b>Daily</b> Cases", secondary_y=True)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.6.3.min.js"></script>                <div id="77472da1-028e-4523-b3f9-c854cbd92537" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("77472da1-028e-4523-b3f9-c854cbd92537")) {                    Plotly.newPlot(                        "77472da1-028e-4523-b3f9-c854cbd92537",                        [{"mode":"lines","name":"Total Infected Case","x":["2020-01-23T00:00:00","2020-01-24T00:00:00","2020-01-26T00:00:00","2020-01-29T00:00:00","2020-01-30T00:00:00","2020-01-31T00:00:00","2020-02-01T00:00:00","2020-02-04T00:00:00","2020-02-05T00:00:00","2020-02-06T00:00:00","2020-02-07T00:00:00","2020-02-09T00:00:00","2020-02-10T00:00:00","2020-02-11T00:00:00","2020-02-12T00:00:00","2020-02-13T00:00:00","2020-02-14T00:00:00","2020-02-16T00:00:00","2020-02-17T00:00:00","2020-02-18T00:00:00","2020-02-19T00:00:00","2020-02-20T00:00:00","2020-02-22T00:00:00","2020-02-23T00:00:00","2020-02-24T00:00:00","2020-02-25T00:00:00","2020-02-26T00:00:00","2020-02-27T00:00:00","2020-02-28T00:00:00","2020-02-29T00:00:00","2020-03-01T00:00:00","2020-03-02T00:00:00","2020-03-04T00:00:00","2020-03-06T00:00:00","2020-03-07T00:00:00","2020-03-08T00:00:00","2020-03-09T00:00:00","2020-03-10T00:00:00","2020-03-11T00:00:00","2020-03-12T00:00:00","2020-03-13T00:00:00","2020-03-14T00:00:00","2020-03-15T00:00:00","2020-03-16T00:00:00","2020-03-17T00:00:00","2020-03-18T00:00:00","2020-03-19T00:00:00","2020-03-20T00:00:00","2020-03-21T00:00:00","2020-03-22T00:00:00","2020-03-23T00:00:00","2020-03-24T00:00:00","2020-03-25T00:00:00","2020-03-26T00:00:00","2020-03-27T00:00:00","2020-03-28T00:00:00","2020-03-29T00:00:00","2020-03-30T00:00:00","2020-03-31T00:00:00","2020-04-01T00:00:00","2020-04-02T00:00:00","2020-04-03T00:00:00","2020-04-04T00:00:00","2020-04-05T00:00:00","2020-04-06T00:00:00","2020-04-07T00:00:00","2020-04-08T00:00:00","2020-04-09T00:00:00","2020-04-10T00:00:00","2020-04-11T00:00:00","2020-04-12T00:00:00","2020-04-13T00:00:00","2020-04-14T00:00:00","2020-04-15T00:00:00","2020-04-16T00:00:00","2020-04-17T00:00:00","2020-04-18T00:00:00","2020-04-19T00:00:00","2020-04-21T00:00:00","2020-04-22T00:00:00","2020-04-23T00:00:00","2020-04-25T00:00:00","2020-05-01T00:00:00","2020-05-04T00:00:00","2020-05-07T00:00:00","2020-05-10T00:00:00","2020-05-13T00:00:00","2020-05-14T00:00:00","2020-05-15T00:00:00","2020-05-17T00:00:00","2020-05-21T00:00:00","2020-05-22T00:00:00","2020-05-27T00:00:00","2020-05-29T00:00:00","2020-05-30T00:00:00","2020-05-31T00:00:00","2020-06-01T00:00:00","2020-06-02T00:00:00","2020-06-04T00:00:00","2020-06-05T00:00:00","2020-06-06T00:00:00","2020-06-07T00:00:00","2020-06-08T00:00:00","2020-06-12T00:00:00","2020-06-13T00:00:00","2020-06-15T00:00:00","2020-06-17T00:00:00","2020-06-18T00:00:00","2020-06-19T00:00:00","2020-06-20T00:00:00","2020-06-21T00:00:00","2020-06-22T00:00:00","2020-06-23T00:00:00","2020-06-24T00:00:00","2020-06-25T00:00:00","2020-06-26T00:00:00","2020-06-27T00:00:00","2020-06-28T00:00:00","2020-06-29T00:00:00","2020-06-30T00:00:00","2020-07-01T00:00:00","2020-07-02T00:00:00","2020-07-03T00:00:00","2020-07-04T00:00:00","2020-07-05T00:00:00","2020-07-06T00:00:00","2020-07-07T00:00:00","2020-07-08T00:00:00","2020-07-09T00:00:00","2020-07-10T00:00:00","2020-07-11T00:00:00","2020-07-12T00:00:00","2020-07-13T00:00:00","2020-07-14T00:00:00","2020-07-15T00:00:00","2020-07-16T00:00:00","2020-07-17T00:00:00","2020-07-18T00:00:00","2020-07-19T00:00:00","2020-07-20T00:00:00","2020-07-21T00:00:00","2020-07-22T00:00:00","2020-07-23T00:00:00","2020-07-24T00:00:00","2020-07-25T00:00:00","2020-07-26T00:00:00","2020-07-27T00:00:00","2020-07-28T00:00:00","2020-07-29T00:00:00","2020-07-30T00:00:00","2020-07-31T00:00:00","2020-08-01T00:00:00","2020-08-02T00:00:00","2020-08-03T00:00:00","2020-08-04T00: ...

# %%
from plotly.subplots import make_subplots

# Create figure with secondary y-axis
fig = make_subplots(specs=[[{"secondary_y": True}]])

fig.add_trace(go_df_bubble_chart(df_cluster2,"Report date","Case no.","Number of cases","Cluster", lineName="Big Cluster"))
fig.add_trace(go_df_count_plot(df_covid,"Report date", lineName="Total Infected Case",mode="cumsum"))
fig.add_trace(go_df_count_plot(df_covid,"Report date", lineName="Daily Infected Case",mode="count"), secondary_y=True)

# Add figure title
fig.update_layout(
    title_text="Summary of Hong Kong COVID19 Cases"
)

# Set x-axis title
fig.update_xaxes(title_text="Date")

# Set y-axes titles
fig.update_yaxes(title_text="<b>Total</b> Cases", secondary_y=False)
fig.update_yaxes(title_text="<b>Daily</b> Cases", secondary_y=True)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="e1bb5d01-97b0-4e1c-80bc-c033285da1c3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e1bb5d01-97b0-4e1c-80bc-c033285da1c3")) {                    Plotly.newPlot(                        "e1bb5d01-97b0-4e1c-80bc-c033285da1c3",                        [{"hovertext": ["Diamond Princess Cruise Ship", "Hotpot dinner gathering at Kwun Tong", "Fook Wai Ching She in Maylun Apartments in North Point", "Travel tour to Egypt / Heng Tai House of Fu Heng Estate", "Bar and band cluster", "Wedding party at Lantau Island", "Kerry Logistics/ Luk Chuen House", "Bun Kee/ Sun Fat/ Kin Wing", "Ming Chuen House of Shui Chuen O Estate", "Kong Tai Care for the Aged Centre", "Tsz Wan Shan Shopping Centre Deluxe Cuisine", "Tsz Wan Shan Shopping Centre Green River", "Tsz Wan Shan Shopping Centre Windsor", "Metropark Hotel Mongkok Victoria Harbour Restaurant", "Grand Plaza Taoheung", "Metroplaza Chiuchow Garden", "Tuen Mun Central Square Fulum Restaurant", "Hung Hom Market", "The Salvation Army Lung Hang Residence For Senior Citizens", "Kwai Tsing Container Terminals", "Cornwall Elderly\u00e2\u0080\u0099s Home (Golden Branch), Tuen Mun", "Star Global Direct Sales", "Kin Shing (Leung's) General Contractors Ltd./ Millennium City 3", "Sheung Shui Slaughter House", "Sham Shui Po King Fok Nursing Home", "Construction site at Kong Nga Po, Man Kam To", "Hong Chi Lei Muk Shue Hostel", "Transport City Building, Tai Wai", "China Secret/Holly Mansion", "The Home of Treasure", "Dancing/Singing Cluster", "Chuen Cheung Kui", "Otto e Mezzo 8\u00c2\u00bd Bombana", "Sky Cuisine (Sheung Wan)", "Tung Wah Group Of Hospitals Fong Shu Chuen Day Activity Centre cum Hostel", "Construction sites at LOHAS Park/ Kai Tak", "Lee Gardens Three Duckee", "YATA Department Store (Shatin)", "AsiaWorld\u00e2\u0080\u0093Expo", "Construction Site at Tseung Kwan O-Lam Tin Tunnel", "Residents of Unit 33/34, Ming Lai House, Choi Wan Estate", "Eastern Artificial Island of the Hong Kong-Zhuhai-Macao Bridge", "Glow Salon and Spa", "Fung Nin Building", "Billy Sir Music Classroom", "Patient and Staff of United Christian Hospital Ward 2D", "Construction Site at Tseung Kwan O-Lam Tin Tunnel (second cluster)", "Cluster related to Central Kowloon Route (Central Tunnel)", "Residents of Unit 09,Yan Shek House, Shek Yam Estate"], "marker": {"size": [11, 13, 19, 10, 103, 15, 12, 46, 12, 46, 32, 38, 26, 15, 42, 20, 44, 13, 15, 77, 40, 61, 32, 24, 14, 23, 24, 17, 15, 20, 732, 12, 23, 22, 61, 74, 16, 28, 25, 29, 13, 13, 17, 14, 16, 21, 50, 37, 10], "sizemin": 1, "sizemode": "area", "sizeref": 0.2}, "mode": "markers", "name": "Big Cluster", "type": "scatter", "x": ["2020-02-01T00:00:00", "2020-02-09T00:00:00", "2020-02-19T00:00:00", "2020-03-10T00:00:00", "2020-03-18T00:00:00", "2020-03-18T00:00:00", "2020-05-31T00:00:00", "2020-07-05T00:00:00", "2020-07-07T00:00:00", "2020-07-07T00:00:00", "2020-07-09T00:00:00", "2020-07-11T00:00:00", "2020-07-13T00:00:00", "2020-07-13T00:00:00", "2020-07-16T00:00:00", "2020-07-18T00:00:00", "2020-07-18T00:00:00", "2020-07-19T00:00:00", "2020-07-22T00:00:00", "2020-07-23T00:00:00", "2020-07-24T00:00:00", "2020-07-24T00:00:00", "2020-07-25T00:00:00", "2020-07-27T00:00:00", "2020-07-30T00:00:00", "2020-07-30T00:00:00", "2020-08-23T00:00:00", "2020-09-02T00:00:00", "2020-10-01T00:00:00", "2020-10-07T00:00:00", "2020-11-19T00:00:00", "2020-11-28T00:00:00", "2020-11-28T00:00:00", "2020-11-28T00:00:00", "2020-11-29T00:00:00", "2020-12-01T00:00:00", "2020-12-03T00:00:00", "2020-12-06T00:00:00", "2020-12-06T00:00:00", "2020-12-09T00:00:00", "2020-12-09T00:00:00", "2020-12-10T00:00:00", "2020-12-11T00:00:00", "2020-12-14T00:00:00", "2020-12-15T00:00:00", "2020-12-24T00:00:00", "2021-01-03T00:00 ...

# %% [markdown]
# # Basic Machine Learning

# %%
# TODO

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=d780ad21-48be-4756-8c0d-30311a37d59d' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
